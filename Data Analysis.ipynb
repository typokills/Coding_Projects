# %% [markdown]
# # Figures and Subplots

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
_ = ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))
fig

# %%
# Reduce white space between grpahs. Will need to edit again later.
ig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)

plt.subplots_adjust(wspace=0, hspace=0)

# %%
# Customizing the lines
from numpy.random import randn
plt.plot(randn(30).cumsum(), 'ko--')

#full form: plot(randn(30).cumsum(), color='k', linestyle='dashed', marker='o')

# %%
data = np.random.randn(30).cumsum()
plt.plot(data, 'k--', label='Default')
plt.plot(data, 'k-', drawstyle='steps-post', label='steps-post')
plt.legend(loc='best')

# %% [markdown]
# ## Ticks, Labels and Legends

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.set_title('My first matplotlib plot')

ax.set_xlabel('Stages')

ticks = ax.set_xticks([0, 250, 500, 750, 1000])
# labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='small')

ax.plot(np.random.randn(1000).cumsum())

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

#Using a dict to set all of the graph stuff
props = {
'title': 'My first matplotlib plot?',
'xlabel': 'Stages'
}
ax.set(**props)

ax.plot(np.random.randn(1000).cumsum())

# %%
#Adding Legends
from numpy.random import randn
fig = plt.figure(); ax = fig.add_subplot(1, 1, 1)
ax.plot(randn(1000).cumsum(), 'k', label='one')
ax.plot(randn(1000).cumsum(), 'k--', label='two')
ax.plot(randn(1000).cumsum(), 'k.', label='three')

#Zoom in
ax.set_xlim([0,800])

#Title
ax.set_title('Important dates in the 2008-2009 financial crisis')

ax.legend(loc='best')

# %% [markdown]
# ## Annotations and Drawing on a subplot

# %%
# from datetime import datetime
# import pandas as pd
# fig = plt.figure()
# ax = fig.add_subplot(1, 1, 1)
# data = np.random.randn(30).cumsum()

# data.plot(ax=ax, style='k-')
# crisis_data = [
# (datetime(2007, 10, 11), 'Peak of bull market'),
# (datetime(2008, 3, 12), 'Bear Stearns Fails'),
# (datetime(2008, 9, 15), 'Lehman Bankruptcy')
# ]

# for date, label in crisis_data:
#     ax.annotate(label, xy=(date, spx.asof(date) + 75),
#     xytext=(date, spx.asof(date) + 225),
#     arrowprops=dict(facecolor='black', headwidth=4, width=2,
#     headlength=4),
#     horizontalalignment='left', verticalalignment='top')
# # Zoom in on 2007-2010
# ax.set_xlim(['1/1/2007', '1/1/2011'])
# ax.set_ylim([600, 1800])
# ax.set_title('Important dates in the 2008-2009 financial crisis')

# %% [markdown]
# ## Adding shapes into graphs

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
color='g', alpha=0.5)
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %% [markdown]
# ## Saving Figures

# %%
# plt.savefig('figpath.png', dpi=400, bbox_inches='tight')

# %%
plt.rc('figure', figsize=(6, 4))

# %%
font_options = {'family' : 'monospace',
                'weight' : 'bold',}
plt.rc('font', **font_options)

# %% [markdown]
# # Plotting with Pandas and Seaborn

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
                  columns=['A', 'B', 'C', 'D'],
                  index=np.arange(0, 100, 10))

df.plot()
# Out:
# <AxesSubplot: >

# %%
fig, axes = plt.subplots(2, 1)
data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))
data.plot.bar(ax=axes[0], color='r', alpha=0.7)
data.plot.barh(ax=axes[1], color='b', alpha=0.7)
# Out:
# <AxesSubplot: >

# %%
df = pd.DataFrame(np.random.rand(6, 4),
                  index=['one', 'two', 'three', 'four', 'five', 'six'],
                  columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))

df
# Out:
# Genus         A         B         C         D
# one    0.788272  0.306646  0.589390  0.631042
# two    0.154848  0.381588  0.598088  0.277302
# three  0.823811  0.144226  0.119874  0.986669
# four   0.405554  0.242694  0.111779  0.200322
# five   0.356208  0.529375  0.618648  0.577641
# six    0.537518  0.497479  0.151816  0.691382

# %%
df.plot.bar()
# Out:
# <AxesSubplot: >

# %%
#Alpha = transparency of the filling
df.plot.barh(stacked=True, alpha=0.5)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Using Seaborne
# If you need summarization and aggregation before plotting.

# %%
import seaborn as sns
comp1 = np.random.normal(0, 1, size=200)
comp2 = np.random.normal(10, 2, size=200)
values = pd.Series(np.concatenate([comp1, comp2]))
sns.distplot(values, bins=100, color='k')
# Out:
# C:\Users\chins\AppData\Local\Temp\ipykernel_33556\3184129512.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(values, bins=100, color='k')
# <AxesSubplot: ylabel='Density'>

# %% [markdown]
# # Data Aggregation and Group Operations

# %%
df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'],
    'key2' : ['one', 'two', 'one', 'two', 'one'],
     'data1' : np.random.randn(5),
     'data2' : np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -0.271043 -1.537381
# 1    a  two -0.463133 -0.325271
# 2    b  one  0.052748  0.154186
# 3    b  two -0.613212  1.559516
# 4    a  one -0.470147  2.183038

# %% [markdown]
# ## Groupby and mean

# %%
grouped = df['data1'].groupby(df['key1'])
grouped.mean()
# Out:
# key1
# a   -0.401441
# b   -0.280232
# Name: data1, dtype: float64

# %%
means = df['data1'].groupby([df['key1'], df['key2']]).mean()
means
# Out:
# key1  key2
# a     one    -0.370595
#       two    -0.463133
# b     one     0.052748
#       two    -0.613212
# Name: data1, dtype: float64

# %%
states = np.array(['Ohio', 'California', 'California', 'Ohio', 'Ohio'])
years = np.array([2005, 2005, 2006, 2005, 2006])
df['data1'].groupby([states, years]).mean()
# Out:
# California  2005   -0.463133
#             2006    0.052748
# Ohio        2005   -0.442127
#             2006   -0.470147
# Name: data1, dtype: float64

# %%
df.groupby(['key1', 'key2']).size()
# Out:
# key1  key2
# a     one     2
#       two     1
# b     one     1
#       two     1
# dtype: int64

# %%
#Pulling out the specific data and group name
for name, group in df.groupby('key1'):
    print(name)
    print(group)
# Out:
# a
#   key1 key2     data1     data2
# 0    a  one -0.271043 -1.537381
# 1    a  two -0.463133 -0.325271
# 4    a  one -0.470147  2.183038
# b
#   key1 key2     data1     data2
# 2    b  one  0.052748  0.154186
# 3    b  two -0.613212  1.559516

# %% [markdown]
# ## Grouping when data comes in dictionaries

# %%
people = pd.DataFrame(np.random.randn(5, 5),
        columns=['a', 'b', 'c', 'd', 'e'],
        index=['Joe', 'Steve', 'Wes', 'Jim', 'Travis'])

#Adding in some nan values
people.iloc[2:3, [1, 2]] = np.nan

people
# Out:
#                a         b         c         d         e
# Joe     0.826866  1.247504 -0.861946 -1.312146  0.156038
# Steve   0.951683 -1.471896  0.612504 -1.695132 -0.909237
# Wes    -0.011265       NaN       NaN -0.202577  0.312481
# Jim    -0.334303 -0.757883  0.137096  1.080531 -0.642424
# Travis -1.025344  0.602037  0.445898  0.492028 -1.286035

# %%
mapping = {'a': 'red', 'b': 'red', 'c': 'blue',
            'd': 'blue', 'e': 'red', 'f' : 'orange'}

#Renames the cols to red/blue and groups them according to the cols
by_column = people.groupby(mapping, axis=1)

by_column.sum()
# Out:
#             blue       red
# Joe    -2.174092  2.230408
# Steve  -1.082629 -1.429449
# Wes    -0.202577  0.301216
# Jim     1.217626 -1.734610
# Travis  0.937927 -1.709342

# %%
map_series = pd.Series(mapping)
map_series
# Out:
# a       red
# b       red
# c      blue
# d      blue
# e       red
# f    orange
# dtype: object

# %%
#Finding the count after grouping
people.groupby(map_series, axis=1).count()
# Out:
#         blue  red
# Joe        2    3
# Steve      2    3
# Wes        1    2
# Jim        2    3
# Travis     2    3

# %% [markdown]
# ## Grouping with Functions

# %%
#Grouping by the len of name
people.groupby(len).sum()
# Out:
#           a         b         c         d         e
# 3  0.481299  0.489621 -0.724851 -0.434192 -0.173906
# 5  0.951683 -1.471896  0.612504 -1.695132 -0.909237
# 6 -1.025344  0.602037  0.445898  0.492028 -1.286035

# %%
#Grouping by col and rows
key_list = ['one', 'one', 'one', 'two', 'two']
people.groupby([len, key_list]).min()
# Out:
#               a         b         c         d         e
# 3 one -0.011265  1.247504 -0.861946 -1.312146  0.156038
#   two -0.334303 -0.757883  0.137096  1.080531 -0.642424
# 5 one  0.951683 -1.471896  0.612504 -1.695132 -0.909237
# 6 two -1.025344  0.602037  0.445898  0.492028 -1.286035

# %%
columns = pd.MultiIndex.from_arrays([['US', 'US', 'US', 'JP', 'JP'],
                                    [1, 3, 5, 1, 3]],
                                     names=['cty', 'tenor'])

hier_df = pd.DataFrame(np.random.randn(4, 5), columns=columns)
hier_df
# Out:
# cty          US                            JP
# tenor         1         3         5         1         3
# 0      0.560230  0.707730 -0.249012 -0.016392 -1.240463
# 1      0.070051  1.033460 -0.859421 -0.085785 -0.135030
# 2     -1.069007  1.139803 -0.856177  0.231911 -1.850541
# 3     -1.113068  0.673458  1.109804 -0.800248  0.963600

# %%
hier_df.groupby(level='cty', axis=1).count()
# Out:
# cty  JP  US
# 0     2   3
# 1     2   3
# 2     2   3
# 3     2   3

# %% [markdown]
# # Aggregation

# %%
#In-built aggregation function
# grouped_pct.agg(['mean', 'std', peak_to_peak])
